# %%
# !ls --help
# Out:
# Usage: ls [OPTION]... [FILE]...
# List information about the FILEs (the current directory by default).
# Sort entries alphabetically if none of -cftuvSUX nor --sort is specified.
#
# Mandatory arguments to long options are mandatory for short options too.
#   -a, --all                  do not ignore entries starting with .
#   -A, --almost-all           do not list implied . and ..
#       --author               with -l, print the author of each file
#   -b, --escape               print C-style escapes for nongraphic characters
#       --block-size=SIZE      with -l, scale sizes by SIZE when printing them;
#                                e.g., '--block-size=M'; see SIZE format below
#   -B, --ignore-backups       do not list implied entries ending with ~
#   -c                         with -lt: sort by, and show, ctime (time of last
#                                modification of file status information);
#                                with -l: show ctime and sort by name;
# ...

# %%
ls
# Out:
# 'Linux Basic.ipynb'   data/   lenv/

# %%
cd data
# Out:
# /home/ajay/data

# %%
pwd
# Out:
# '/home/ajay/data'

# %%
ls
# Out:
# README.md  electionresults/  hr_db/  nyse/      retail_db/
# cards/     hr/               lca/    nyse_all/  retail_db_json/

# %%
ls -l
# Out:
# total 40
# -rw-r--r--  1 ajay ajay  160 Mar  8 15:31 README.md
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 cards/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 electionresults/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 hr/
# drwxr-xr-x 10 ajay ajay 4096 Mar  8 15:31 hr_db/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 lca/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 nyse/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 nyse_all/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db_json/

# %%
ls -ltr
# Out:
# total 40
# -rw-r--r--  1 ajay ajay  160 Mar  8 15:31 README.md
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 cards/
# drwxr-xr-x 10 ajay ajay 4096 Mar  8 15:31 hr_db/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 hr/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 electionresults/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 lca/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 nyse/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 nyse_all/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db_json/

# %%
ls -l
# Out:
# total 40
# -rw-r--r--  1 ajay ajay  160 Mar  8 15:31 README.md
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 cards/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 electionresults/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 hr/
# drwxr-xr-x 10 ajay ajay 4096 Mar  8 15:31 hr_db/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 lca/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 nyse/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 nyse_all/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db_json/

# %%
ls -lr
# Out:
# total 40
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db_json/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 nyse_all/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 nyse/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 lca/
# drwxr-xr-x 10 ajay ajay 4096 Mar  8 15:31 hr_db/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 hr/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 electionresults/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 cards/
# -rw-r--r--  1 ajay ajay  160 Mar  8 15:31 README.md

# %%
ls -r
# Out:
# retail_db_json/  nyse_all/  lca/    hr/               cards/
# retail_db/       nyse/      hr_db/  electionresults/  README.md

# %%
ls -ltr
# Out:
# total 40
# -rw-r--r--  1 ajay ajay  160 Mar  8 15:31 README.md
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 cards/
# drwxr-xr-x 10 ajay ajay 4096 Mar  8 15:31 hr_db/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 hr/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 electionresults/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 lca/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 nyse/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 nyse_all/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db_json/

# %%
ls -l
# Out:
# total 40
# -rw-r--r--  1 ajay ajay  160 Mar  8 15:31 README.md
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 cards/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 electionresults/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 hr/
# drwxr-xr-x 10 ajay ajay 4096 Mar  8 15:31 hr_db/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 lca/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 nyse/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 nyse_all/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db_json/

# %% [markdown]
# - Files are shorted by time

# %%
ls -lt
# Out:
# total 40
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db_json/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 nyse_all/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 nyse/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 lca/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 electionresults/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 hr/
# drwxr-xr-x 10 ajay ajay 4096 Mar  8 15:31 hr_db/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 cards/
# -rw-r--r--  1 ajay ajay  160 Mar  8 15:31 README.md

# %% [markdown]
# touch lca

# %%
ls -lt
# Out:
# total 40
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:59 lca/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db_json/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 nyse_all/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 nyse/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 electionresults/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 hr/
# drwxr-xr-x 10 ajay ajay 4096 Mar  8 15:31 hr_db/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 cards/
# -rw-r--r--  1 ajay ajay  160 Mar  8 15:31 README.md

# %% [markdown]
# touch cards

# %% [markdown]
# data is sorted is deccending order

# %%
ls -lt
# Out:
# total 40
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 16:01 cards/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:59 lca/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db_json/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 nyse_all/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 nyse/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 electionresults/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 hr/
# drwxr-xr-x 10 ajay ajay 4096 Mar  8 15:31 hr_db/
# -rw-r--r--  1 ajay ajay  160 Mar  8 15:31 README.md

# %% [markdown]
# data is sorted by accending order

# %%
ls -ltr
# Out:
# total 40
# -rw-r--r--  1 ajay ajay  160 Mar  8 15:31 README.md
# drwxr-xr-x 10 ajay ajay 4096 Mar  8 15:31 hr_db/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 hr/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 electionresults/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 nyse/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 nyse_all/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db_json/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:59 lca/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 16:01 cards/

# %%
ls -l -t -r
# Out:
# total 40
# -rw-r--r--  1 ajay ajay  160 Mar  8 15:31 README.md
# drwxr-xr-x 10 ajay ajay 4096 Mar  8 15:31 hr_db/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 hr/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 electionresults/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 nyse/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 nyse_all/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db_json/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:59 lca/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 16:01 cards/

# %% [markdown]
# # Sorted by Size

# %%
ls --help
# Out:
# Usage: ls [OPTION]... [FILE]...
# List information about the FILEs (the current directory by default).
# Sort entries alphabetically if none of -cftuvSUX nor --sort is specified.
#
# Mandatory arguments to long options are mandatory for short options too.
#   -a, --all                  do not ignore entries starting with .
#   -A, --almost-all           do not list implied . and ..
#       --author               with -l, print the author of each file
#   -b, --escape               print C-style escapes for nongraphic characters
#       --block-size=SIZE      with -l, scale sizes by SIZE when printing them;
#                                e.g., '--block-size=M'; see SIZE format below
#   -B, --ignore-backups       do not list implied entries ending with ~
#   -c                         with -lt: sort by, and show, ctime (time of last
#                                modification of file status information);
#                                with -l: show ctime and sort by name;
# ...

# %%
pwd
# Out:
# '/home/ajay/data/nyse_all'

# %%
ls
# Out:
# nyse_data/  nyse_stocks/

# %%
cd nyse_data/
# Out:
# /home/ajay/data/nyse_all/nyse_data

# %%
ls -l
# Out:
# total 136020
# -rw-r--r-- 1 ajay ajay  3842443 Mar  8 15:31 NYSE_1997.txt.gz
# -rw-r--r-- 1 ajay ajay  4142942 Mar  8 15:31 NYSE_1998.txt.gz
# -rw-r--r-- 1 ajay ajay  4297025 Mar  8 15:31 NYSE_1999.txt.gz
# -rw-r--r-- 1 ajay ajay  4439306 Mar  8 15:31 NYSE_2000.txt.gz
# -rw-r--r-- 1 ajay ajay  4722623 Mar  8 15:31 NYSE_2001.txt.gz
# -rw-r--r-- 1 ajay ajay  5021940 Mar  8 15:31 NYSE_2002.txt.gz
# -rw-r--r-- 1 ajay ajay  5271305 Mar  8 15:31 NYSE_2003.txt.gz
# -rw-r--r-- 1 ajay ajay  5689069 Mar  8 15:31 NYSE_2004.txt.gz
# -rw-r--r-- 1 ajay ajay  6207833 Mar  8 15:31 NYSE_2005.txt.gz
# -rw-r--r-- 1 ajay ajay  6480175 Mar  8 15:31 NYSE_2006.txt.gz
# -rw-r--r-- 1 ajay ajay  6903056 Mar  8 15:31 NYSE_2007.txt.gz
# -rw-r--r-- 1 ajay ajay  7179621 Mar  8 15:31 NYSE_2008.txt.gz
# -rw-r--r-- 1 ajay ajay  7186235 Mar  8 15:31 NYSE_2009.txt.gz
# -rw-r--r-- 1 ajay ajay  7551218 Mar  8 15:31 NYSE_2010.txt.gz
# -rw-r--r-- 1 ajay ajay  7980961 Mar  8 15:31 NYSE_2011.txt.gz
# ...

# %%
ls -S
# Out:
# NYSE_2016.txt.gz  NYSE_2010.txt.gz  NYSE_2004.txt.gz  NYSE_1998.txt.gz
# NYSE_2015.txt.gz  NYSE_2009.txt.gz  NYSE_2003.txt.gz  NYSE_1997.txt.gz
# NYSE_2014.txt.gz  NYSE_2008.txt.gz  NYSE_2002.txt.gz  NYSE_2017.txt.gz
# NYSE_2013.txt.gz  NYSE_2007.txt.gz  NYSE_2001.txt.gz
# NYSE_2012.txt.gz  NYSE_2006.txt.gz  NYSE_2000.txt.gz
# NYSE_2011.txt.gz  NYSE_2005.txt.gz  NYSE_1999.txt.gz

# %% [raw]
# files are sorted by size in deccending order.

# %%
ls -lS
# Out:
# total 136020
# -rw-r--r-- 1 ajay ajay 11796756 Mar  8 15:31 NYSE_2016.txt.gz
# -rw-r--r-- 1 ajay ajay 11327417 Mar  8 15:31 NYSE_2015.txt.gz
# -rw-r--r-- 1 ajay ajay 10552757 Mar  8 15:31 NYSE_2014.txt.gz
# -rw-r--r-- 1 ajay ajay  9588984 Mar  8 15:31 NYSE_2013.txt.gz
# -rw-r--r-- 1 ajay ajay  8538688 Mar  8 15:31 NYSE_2012.txt.gz
# -rw-r--r-- 1 ajay ajay  7980961 Mar  8 15:31 NYSE_2011.txt.gz
# -rw-r--r-- 1 ajay ajay  7551218 Mar  8 15:31 NYSE_2010.txt.gz
# -rw-r--r-- 1 ajay ajay  7186235 Mar  8 15:31 NYSE_2009.txt.gz
# -rw-r--r-- 1 ajay ajay  7179621 Mar  8 15:31 NYSE_2008.txt.gz
# -rw-r--r-- 1 ajay ajay  6903056 Mar  8 15:31 NYSE_2007.txt.gz
# -rw-r--r-- 1 ajay ajay  6480175 Mar  8 15:31 NYSE_2006.txt.gz
# -rw-r--r-- 1 ajay ajay  6207833 Mar  8 15:31 NYSE_2005.txt.gz
# -rw-r--r-- 1 ajay ajay  5689069 Mar  8 15:31 NYSE_2004.txt.gz
# -rw-r--r-- 1 ajay ajay  5271305 Mar  8 15:31 NYSE_2003.txt.gz
# -rw-r--r-- 1 ajay ajay  5021940 Mar  8 15:31 NYSE_2002.txt.gz
# ...

# %% [markdown]
# sorted by size in accending order

# %%
ls -lSr
# Out:
# total 136020
# -rw-r--r-- 1 ajay ajay   519586 Mar  8 15:31 NYSE_2017.txt.gz
# -rw-r--r-- 1 ajay ajay  3842443 Mar  8 15:31 NYSE_1997.txt.gz
# -rw-r--r-- 1 ajay ajay  4142942 Mar  8 15:31 NYSE_1998.txt.gz
# -rw-r--r-- 1 ajay ajay  4297025 Mar  8 15:31 NYSE_1999.txt.gz
# -rw-r--r-- 1 ajay ajay  4439306 Mar  8 15:31 NYSE_2000.txt.gz
# -rw-r--r-- 1 ajay ajay  4722623 Mar  8 15:31 NYSE_2001.txt.gz
# -rw-r--r-- 1 ajay ajay  5021940 Mar  8 15:31 NYSE_2002.txt.gz
# -rw-r--r-- 1 ajay ajay  5271305 Mar  8 15:31 NYSE_2003.txt.gz
# -rw-r--r-- 1 ajay ajay  5689069 Mar  8 15:31 NYSE_2004.txt.gz
# -rw-r--r-- 1 ajay ajay  6207833 Mar  8 15:31 NYSE_2005.txt.gz
# -rw-r--r-- 1 ajay ajay  6480175 Mar  8 15:31 NYSE_2006.txt.gz
# -rw-r--r-- 1 ajay ajay  6903056 Mar  8 15:31 NYSE_2007.txt.gz
# -rw-r--r-- 1 ajay ajay  7179621 Mar  8 15:31 NYSE_2008.txt.gz
# -rw-r--r-- 1 ajay ajay  7186235 Mar  8 15:31 NYSE_2009.txt.gz
# -rw-r--r-- 1 ajay ajay  7551218 Mar  8 15:31 NYSE_2010.txt.gz
# ...

# %%
ls -ltr
# Out:
# total 136020
# -rw-r--r-- 1 ajay ajay  4142942 Mar  8 15:31 NYSE_1998.txt.gz
# -rw-r--r-- 1 ajay ajay  3842443 Mar  8 15:31 NYSE_1997.txt.gz
# -rw-r--r-- 1 ajay ajay  4439306 Mar  8 15:31 NYSE_2000.txt.gz
# -rw-r--r-- 1 ajay ajay  4297025 Mar  8 15:31 NYSE_1999.txt.gz
# -rw-r--r-- 1 ajay ajay  5021940 Mar  8 15:31 NYSE_2002.txt.gz
# -rw-r--r-- 1 ajay ajay  4722623 Mar  8 15:31 NYSE_2001.txt.gz
# -rw-r--r-- 1 ajay ajay  5689069 Mar  8 15:31 NYSE_2004.txt.gz
# -rw-r--r-- 1 ajay ajay  5271305 Mar  8 15:31 NYSE_2003.txt.gz
# -rw-r--r-- 1 ajay ajay  6207833 Mar  8 15:31 NYSE_2005.txt.gz
# -rw-r--r-- 1 ajay ajay  6480175 Mar  8 15:31 NYSE_2006.txt.gz
# -rw-r--r-- 1 ajay ajay  6903056 Mar  8 15:31 NYSE_2007.txt.gz
# -rw-r--r-- 1 ajay ajay  7186235 Mar  8 15:31 NYSE_2009.txt.gz
# -rw-r--r-- 1 ajay ajay  7179621 Mar  8 15:31 NYSE_2008.txt.gz
# -rw-r--r-- 1 ajay ajay  7551218 Mar  8 15:31 NYSE_2010.txt.gz
# -rw-r--r-- 1 ajay ajay  7980961 Mar  8 15:31 NYSE_2011.txt.gz
# ...

# %%
touch NYSE_1998.txt.gz

# %%
ls -ltr
# Out:
# total 136020
# -rw-r--r-- 1 ajay ajay  3842443 Mar  8 15:31 NYSE_1997.txt.gz
# -rw-r--r-- 1 ajay ajay  4439306 Mar  8 15:31 NYSE_2000.txt.gz
# -rw-r--r-- 1 ajay ajay  4297025 Mar  8 15:31 NYSE_1999.txt.gz
# -rw-r--r-- 1 ajay ajay  5021940 Mar  8 15:31 NYSE_2002.txt.gz
# -rw-r--r-- 1 ajay ajay  4722623 Mar  8 15:31 NYSE_2001.txt.gz
# -rw-r--r-- 1 ajay ajay  5689069 Mar  8 15:31 NYSE_2004.txt.gz
# -rw-r--r-- 1 ajay ajay  5271305 Mar  8 15:31 NYSE_2003.txt.gz
# -rw-r--r-- 1 ajay ajay  6207833 Mar  8 15:31 NYSE_2005.txt.gz
# -rw-r--r-- 1 ajay ajay  6480175 Mar  8 15:31 NYSE_2006.txt.gz
# -rw-r--r-- 1 ajay ajay  6903056 Mar  8 15:31 NYSE_2007.txt.gz
# -rw-r--r-- 1 ajay ajay  7186235 Mar  8 15:31 NYSE_2009.txt.gz
# -rw-r--r-- 1 ajay ajay  7179621 Mar  8 15:31 NYSE_2008.txt.gz
# -rw-r--r-- 1 ajay ajay  7551218 Mar  8 15:31 NYSE_2010.txt.gz
# -rw-r--r-- 1 ajay ajay  7980961 Mar  8 15:31 NYSE_2011.txt.gz
# -rw-r--r-- 1 ajay ajay  8538688 Mar  8 15:31 NYSE_2012.txt.gz
# ...

# %%
ls -lSt
# Out:
# total 136020
# -rw-r--r-- 1 ajay ajay  4142942 Mar  8 16:56 NYSE_1998.txt.gz
# -rw-r--r-- 1 ajay ajay 11796756 Mar  8 15:31 NYSE_2016.txt.gz
# -rw-r--r-- 1 ajay ajay   519586 Mar  8 15:31 NYSE_2017.txt.gz
# -rw-r--r-- 1 ajay ajay 11327417 Mar  8 15:31 NYSE_2015.txt.gz
# -rw-r--r-- 1 ajay ajay 10552757 Mar  8 15:31 NYSE_2014.txt.gz
# -rw-r--r-- 1 ajay ajay  9588984 Mar  8 15:31 NYSE_2013.txt.gz
# -rw-r--r-- 1 ajay ajay  8538688 Mar  8 15:31 NYSE_2012.txt.gz
# -rw-r--r-- 1 ajay ajay  7980961 Mar  8 15:31 NYSE_2011.txt.gz
# -rw-r--r-- 1 ajay ajay  7551218 Mar  8 15:31 NYSE_2010.txt.gz
# -rw-r--r-- 1 ajay ajay  7179621 Mar  8 15:31 NYSE_2008.txt.gz
# -rw-r--r-- 1 ajay ajay  7186235 Mar  8 15:31 NYSE_2009.txt.gz
# -rw-r--r-- 1 ajay ajay  6903056 Mar  8 15:31 NYSE_2007.txt.gz
# -rw-r--r-- 1 ajay ajay  6480175 Mar  8 15:31 NYSE_2006.txt.gz
# -rw-r--r-- 1 ajay ajay  6207833 Mar  8 15:31 NYSE_2005.txt.gz
# -rw-r--r-- 1 ajay ajay  5271305 Mar  8 15:31 NYSE_2003.txt.gz
# ...

# %%
ls -ltSr
# Out:
# total 136020
# -rw-r--r-- 1 ajay ajay   519586 Mar  8 15:31 NYSE_2017.txt.gz
# -rw-r--r-- 1 ajay ajay  3842443 Mar  8 15:31 NYSE_1997.txt.gz
# -rw-r--r-- 1 ajay ajay  4142942 Mar  8 16:56 NYSE_1998.txt.gz
# -rw-r--r-- 1 ajay ajay  4297025 Mar  8 15:31 NYSE_1999.txt.gz
# -rw-r--r-- 1 ajay ajay  4439306 Mar  8 15:31 NYSE_2000.txt.gz
# -rw-r--r-- 1 ajay ajay  4722623 Mar  8 15:31 NYSE_2001.txt.gz
# -rw-r--r-- 1 ajay ajay  5021940 Mar  8 15:31 NYSE_2002.txt.gz
# -rw-r--r-- 1 ajay ajay  5271305 Mar  8 15:31 NYSE_2003.txt.gz
# -rw-r--r-- 1 ajay ajay  5689069 Mar  8 15:31 NYSE_2004.txt.gz
# -rw-r--r-- 1 ajay ajay  6207833 Mar  8 15:31 NYSE_2005.txt.gz
# -rw-r--r-- 1 ajay ajay  6480175 Mar  8 15:31 NYSE_2006.txt.gz
# -rw-r--r-- 1 ajay ajay  6903056 Mar  8 15:31 NYSE_2007.txt.gz
# -rw-r--r-- 1 ajay ajay  7179621 Mar  8 15:31 NYSE_2008.txt.gz
# -rw-r--r-- 1 ajay ajay  7186235 Mar  8 15:31 NYSE_2009.txt.gz
# -rw-r--r-- 1 ajay ajay  7551218 Mar  8 15:31 NYSE_2010.txt.gz
# ...

# %% [markdown]
# # Listing Hidden Files and Folders in Linux

# %%
cd ~
# Out:
# /home/ajay

# %%
pwd
# Out:
# '/home/ajay'

# %%
ls -ltr
# Out:
# total 64
# drwxr-xr-x 12 ajay ajay  4096 Mar  8 15:31  data/
# drwxr-xr-x  7 ajay ajay  4096 Mar  8 15:37  lenv/
# -rw-r--r--  1 ajay ajay 54513 Mar  8 17:11 'Linux Basic.ipynb'

# %%
ls --help
# Out:
# Usage: ls [OPTION]... [FILE]...
# List information about the FILEs (the current directory by default).
# Sort entries alphabetically if none of -cftuvSUX nor --sort is specified.
#
# Mandatory arguments to long options are mandatory for short options too.
#   -a, --all                  do not ignore entries starting with .
#   -A, --almost-all           do not list implied . and ..
#       --author               with -l, print the author of each file
#   -b, --escape               print C-style escapes for nongraphic characters
#       --block-size=SIZE      with -l, scale sizes by SIZE when printing them;
#                                e.g., '--block-size=M'; see SIZE format below
#   -B, --ignore-backups       do not list implied entries ending with ~
#   -c                         with -lt: sort by, and show, ctime (time of last
#                                modification of file status information);
#                                with -l: show ctime and sort by name;
# ...

# %% [markdown]
# Show hiiden files

# %%
ls -a
# Out:
#  ./              .bash_logout          .ipython/     .python_history
#  ../             .bashrc               .jupyter/     .sudo_as_admin_successful
#  .aws@           .cache/               .local/      'Linux Basic.ipynb'
#  .azure@         .docker/              .motd_shown   data/
#  .bash_history   .ipynb_checkpoints/   .profile      lenv/

# %%
ls -la
# Out:
# total 128
# drwxr-x--- 10 ajay ajay  4096 Mar  9 17:43  ./
# drwxr-xr-x  4 root root  4096 Feb 15 17:36  ../
# lrwxrwxrwx  1 ajay ajay    22 Feb 15 17:36  .aws -> /mnt/c/Users/DELL/.aws/
# lrwxrwxrwx  1 ajay ajay    24 Feb 15 17:36  .azure -> /mnt/c/Users/DELL/.azure/
# -rw-------  1 ajay ajay   982 Mar  4 10:57  .bash_history
# -rw-r--r--  1 ajay ajay   220 Feb 13 17:49  .bash_logout
# -rw-r--r--  1 ajay ajay  3771 Feb 13 17:49  .bashrc
# drwxr-xr-x  4 ajay ajay  4096 Mar  8 16:48  .cache/
# drwxr-xr-x  5 ajay ajay  4096 Feb 15 17:36  .docker/
# drwxr-xr-x  2 ajay ajay  4096 Mar  8 15:43  .ipynb_checkpoints/
# drwxr-xr-x  3 ajay ajay  4096 Mar  8 15:42  .ipython/
# drwxr-xr-x  4 ajay ajay  4096 Mar  8 15:39  .jupyter/
# drwxr-xr-x  3 ajay ajay  4096 Feb 21 07:24  .local/
# -rw-r--r--  1 ajay ajay     0 Mar  8 15:27  .motd_shown
# -rw-r--r--  1 ajay ajay   807 Feb 13 17:49  .profile
# -rw-------  1 ajay ajay    70 Feb 16 16:56  .python_history
# ...

# %%
ls -lat
# Out:
# total 128
# drwxr-x--- 10 ajay ajay  4096 Mar  9 17:59  ./
# -rw-r--r--  1 ajay ajay 68456 Mar  9 17:59 'Linux Basic.ipynb'
# drwxr-xr-x  4 ajay ajay  4096 Mar  8 16:48  .cache/
# drwxr-xr-x  2 ajay ajay  4096 Mar  8 15:43  .ipynb_checkpoints/
# drwxr-xr-x  3 ajay ajay  4096 Mar  8 15:42  .ipython/
# drwxr-xr-x  4 ajay ajay  4096 Mar  8 15:39  .jupyter/
# drwxr-xr-x  7 ajay ajay  4096 Mar  8 15:37  lenv/
# drwxr-xr-x 12 ajay ajay  4096 Mar  8 15:31  data/
# -rw-r--r--  1 ajay ajay     0 Mar  8 15:27  .motd_shown
# -rw-------  1 ajay ajay   982 Mar  4 10:57  .bash_history
# drwxr-xr-x  3 ajay ajay  4096 Feb 21 07:24  .local/
# -rw-------  1 ajay ajay    70 Feb 16 16:56  .python_history
# drwxr-xr-x  5 ajay ajay  4096 Feb 15 17:36  .docker/
# lrwxrwxrwx  1 ajay ajay    24 Feb 15 17:36  .azure -> /mnt/c/Users/DELL/.azure/
# lrwxrwxrwx  1 ajay ajay    22 Feb 15 17:36  .aws -> /mnt/c/Users/DELL/.aws/
# drwxr-xr-x  4 root root  4096 Feb 15 17:36  ../
# ...

# %%
ls -altr
# Out:
# total 128
# -rw-r--r--  1 ajay ajay   807 Feb 13 17:49  .profile
# -rw-r--r--  1 ajay ajay  3771 Feb 13 17:49  .bashrc
# -rw-r--r--  1 ajay ajay   220 Feb 13 17:49  .bash_logout
# -rw-r--r--  1 ajay ajay     0 Feb 15 17:36  .sudo_as_admin_successful
# drwxr-xr-x  4 root root  4096 Feb 15 17:36  ../
# lrwxrwxrwx  1 ajay ajay    22 Feb 15 17:36  .aws -> /mnt/c/Users/DELL/.aws/
# lrwxrwxrwx  1 ajay ajay    24 Feb 15 17:36  .azure -> /mnt/c/Users/DELL/.azure/
# drwxr-xr-x  5 ajay ajay  4096 Feb 15 17:36  .docker/
# -rw-------  1 ajay ajay    70 Feb 16 16:56  .python_history
# drwxr-xr-x  3 ajay ajay  4096 Feb 21 07:24  .local/
# -rw-------  1 ajay ajay   982 Mar  4 10:57  .bash_history
# -rw-r--r--  1 ajay ajay     0 Mar  8 15:27  .motd_shown
# drwxr-xr-x 12 ajay ajay  4096 Mar  8 15:31  data/
# drwxr-xr-x  7 ajay ajay  4096 Mar  8 15:37  lenv/
# drwxr-xr-x  4 ajay ajay  4096 Mar  8 15:39  .jupyter/
# drwxr-xr-x  3 ajay ajay  4096 Mar  8 15:42  .ipython/
# ...

# %%
ls -alSr
# Out:
# total 128
# -rw-r--r--  1 ajay ajay     0 Feb 15 17:36  .sudo_as_admin_successful
# -rw-r--r--  1 ajay ajay     0 Mar  8 15:27  .motd_shown
# lrwxrwxrwx  1 ajay ajay    22 Feb 15 17:36  .aws -> /mnt/c/Users/DELL/.aws/
# lrwxrwxrwx  1 ajay ajay    24 Feb 15 17:36  .azure -> /mnt/c/Users/DELL/.azure/
# -rw-------  1 ajay ajay    70 Feb 16 16:56  .python_history
# -rw-r--r--  1 ajay ajay   220 Feb 13 17:49  .bash_logout
# -rw-r--r--  1 ajay ajay   807 Feb 13 17:49  .profile
# -rw-------  1 ajay ajay   982 Mar  4 10:57  .bash_history
# -rw-r--r--  1 ajay ajay  3771 Feb 13 17:49  .bashrc
# drwxr-xr-x  7 ajay ajay  4096 Mar  8 15:37  lenv/
# drwxr-xr-x 12 ajay ajay  4096 Mar  8 15:31  data/
# drwxr-xr-x  3 ajay ajay  4096 Feb 21 07:24  .local/
# drwxr-xr-x  4 ajay ajay  4096 Mar  8 15:39  .jupyter/
# drwxr-xr-x  3 ajay ajay  4096 Mar  8 15:42  .ipython/
# drwxr-xr-x  2 ajay ajay  4096 Mar  8 15:43  .ipynb_checkpoints/
# drwxr-xr-x  5 ajay ajay  4096 Feb 15 17:36  .docker/
# ...

# %%
pwd
# Out:
# '/home/ajay'

# %%
cd data/retail_db/
# Out:
# /home/ajay/data/retail_db

# %%
pwd
# Out:
# '/home/ajay/data/retail_db'

# %%
ls -ltr
# Out:
# total 20164
# drwxr-xr-x 2 ajay ajay     4096 Mar  8 15:31 categories/
# -rw-r--r-- 1 ajay ajay      806 Mar  8 15:31 README.md
# drwxr-xr-x 2 ajay ajay     4096 Mar  8 15:31 departments/
# drwxr-xr-x 2 ajay ajay     4096 Mar  8 15:31 customers/
# -rw-r--r-- 1 ajay ajay     1748 Mar  8 15:31 create_db_tables_pg.sql
# -rw-r--r-- 1 ajay ajay 10303297 Mar  8 15:31 create_db.sql
# drwxr-xr-x 2 ajay ajay     4096 Mar  8 15:31 order_items/
# -rw-r--r-- 1 ajay ajay 10297372 Mar  8 15:31 load_db_tables_pg.sql
# drwxr-xr-x 2 ajay ajay     4096 Mar  8 15:31 orders/
# -rw-r--r-- 1 ajay ajay     4255 Mar  8 15:31 schemas.json
# drwxr-xr-x 2 ajay ajay     4096 Mar  8 15:31 products/

# %% [markdown]
# Recursive

# %%
ls -R
# Out:
# .:
# README.md      create_db_tables_pg.sql  load_db_tables_pg.sql  products/
# categories/    customers/               order_items/           schemas.json
# create_db.sql  departments/             orders/
#
# ./categories:
# part-00000
#
# ./customers:
# part-00000
#
# ./departments:
# part-00000
#
# ./order_items:
# part-00000
#
# ./orders:
# part-00000
#
# ./products:
# part-00000

# %%
ls -lR
# Out:
# .:
# total 20164
# -rw-r--r-- 1 ajay ajay      806 Mar  8 15:31 README.md
# drwxr-xr-x 2 ajay ajay     4096 Mar  8 15:31 categories/
# -rw-r--r-- 1 ajay ajay 10303297 Mar  8 15:31 create_db.sql
# -rw-r--r-- 1 ajay ajay     1748 Mar  8 15:31 create_db_tables_pg.sql
# drwxr-xr-x 2 ajay ajay     4096 Mar  8 15:31 customers/
# drwxr-xr-x 2 ajay ajay     4096 Mar  8 15:31 departments/
# -rw-r--r-- 1 ajay ajay 10297372 Mar  8 15:31 load_db_tables_pg.sql
# drwxr-xr-x 2 ajay ajay     4096 Mar  8 15:31 order_items/
# drwxr-xr-x 2 ajay ajay     4096 Mar  8 15:31 orders/
# drwxr-xr-x 2 ajay ajay     4096 Mar  8 15:31 products/
# -rw-r--r-- 1 ajay ajay     4255 Mar  8 15:31 schemas.json
#
# ./categories:
# total 4
# -rw-r--r-- 1 ajay ajay 1029 Mar  8 15:31 part-00000
#
# ./customers:
# total 932
# -rw-r--r-- 1 ajay ajay 953719 Mar  8 15:31 part-00000
#
# ./departments:
# total 4
# -rw-r--r-- 1 ajay ajay 60 Mar  8 15:31 part-00000
#
# ./order_items:
# total 5284
# ...

# %%
cd ..
# Out:
# /home/ajay/data

# %%
ls -lR
# Out:
# .:
# total 40
# -rw-r--r--  1 ajay ajay  160 Mar  8 15:31 README.md
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 16:01 cards/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 electionresults/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 hr/
# drwxr-xr-x 10 ajay ajay 4096 Mar  8 15:31 hr_db/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:59 lca/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 nyse/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 nyse_all/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db_json/
#
# ./cards:
# total 3456
# -rw-r--r-- 1 ajay ajay     693 Mar  8 15:31 deckofcards.txt
# -rw-r--r-- 1 ajay ajay 3523170 Mar  8 15:31 largedeck.txt.gz
# drwxr-xr-x 2 ajay ajay    4096 Mar  8 15:31 smalldecks/
# drwxr-xr-x 2 ajay ajay    4096 Mar  8 15:31 zippeddecks/
#
# ./cards/smalldecks:
# total 16476
# -rw-r--r-- 1 ajay ajay  5516828 Mar  8 15:31 deckofcards.tar.gz
# -rw-r--r-- 1 ajay ajay 11354112 Mar  8 15:31 deckofcards.txt
#
# ...

# %%
cd nyse/
# Out:
# /home/ajay/data/nyse

# %%
ls -lR
# Out:
# .:
# total 50880
# -rw-r--r-- 1 ajay ajay   394993 Mar  8 15:31 companylist_noheader.csv
# -rw-r--r-- 1 ajay ajay 51701267 Mar  8 15:31 nyse_data.tar.gz

# %%
cd ..
# Out:
# /home/ajay/data

# %%
ls -ltr
# Out:
# total 40
# -rw-r--r--  1 ajay ajay  160 Mar  8 15:31 README.md
# drwxr-xr-x 10 ajay ajay 4096 Mar  8 15:31 hr_db/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 hr/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 electionresults/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 nyse/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 nyse_all/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db_json/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:59 lca/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 16:01 cards/

# %%
ls -lR
# Out:
# .:
# total 40
# -rw-r--r--  1 ajay ajay  160 Mar  8 15:31 README.md
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 16:01 cards/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 electionresults/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 hr/
# drwxr-xr-x 10 ajay ajay 4096 Mar  8 15:31 hr_db/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:59 lca/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 nyse/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 nyse_all/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db_json/
#
# ./cards:
# total 3456
# -rw-r--r-- 1 ajay ajay     693 Mar  8 15:31 deckofcards.txt
# -rw-r--r-- 1 ajay ajay 3523170 Mar  8 15:31 largedeck.txt.gz
# drwxr-xr-x 2 ajay ajay    4096 Mar  8 15:31 smalldecks/
# drwxr-xr-x 2 ajay ajay    4096 Mar  8 15:31 zippeddecks/
#
# ./cards/smalldecks:
# total 16476
# -rw-r--r-- 1 ajay ajay  5516828 Mar  8 15:31 deckofcards.tar.gz
# -rw-r--r-- 1 ajay ajay 11354112 Mar  8 15:31 deckofcards.txt
#
# ...

# %%
cd nyse_all/
# Out:
# /home/ajay/data/nyse_all

# %%
ls -lR
# Out:
# .:
# total 8
# drwxr-xr-x 2 ajay ajay 4096 Mar  8 15:31 nyse_data/
# drwxr-xr-x 2 ajay ajay 4096 Mar  8 15:31 nyse_stocks/
#
# ./nyse_data:
# total 136020
# -rw-r--r-- 1 ajay ajay  3842443 Mar  8 15:31 NYSE_1997.txt.gz
# -rw-r--r-- 1 ajay ajay  4142942 Mar  8 16:56 NYSE_1998.txt.gz
# -rw-r--r-- 1 ajay ajay  4297025 Mar  8 15:31 NYSE_1999.txt.gz
# -rw-r--r-- 1 ajay ajay  4439306 Mar  8 15:31 NYSE_2000.txt.gz
# -rw-r--r-- 1 ajay ajay  4722623 Mar  8 15:31 NYSE_2001.txt.gz
# -rw-r--r-- 1 ajay ajay  5021940 Mar  8 15:31 NYSE_2002.txt.gz
# -rw-r--r-- 1 ajay ajay  5271305 Mar  8 15:31 NYSE_2003.txt.gz
# -rw-r--r-- 1 ajay ajay  5689069 Mar  8 15:31 NYSE_2004.txt.gz
# -rw-r--r-- 1 ajay ajay  6207833 Mar  8 15:31 NYSE_2005.txt.gz
# -rw-r--r-- 1 ajay ajay  6480175 Mar  8 15:31 NYSE_2006.txt.gz
# -rw-r--r-- 1 ajay ajay  6903056 Mar  8 15:31 NYSE_2007.txt.gz
# -rw-r--r-- 1 ajay ajay  7179621 Mar  8 15:31 NYSE_2008.txt.gz
# -rw-r--r-- 1 ajay ajay  7186235 Mar  8 15:31 NYSE_2009.txt.gz
# ...

# %%
ls -ltR
# Out:
# .:
# total 8
# drwxr-xr-x 2 ajay ajay 4096 Mar  8 15:31 nyse_data/
# drwxr-xr-x 2 ajay ajay 4096 Mar  8 15:31 nyse_stocks/
#
# ./nyse_data:
# total 136020
# -rw-r--r-- 1 ajay ajay  4142942 Mar  8 16:56 NYSE_1998.txt.gz
# -rw-r--r-- 1 ajay ajay 11796756 Mar  8 15:31 NYSE_2016.txt.gz
# -rw-r--r-- 1 ajay ajay   519586 Mar  8 15:31 NYSE_2017.txt.gz
# -rw-r--r-- 1 ajay ajay 11327417 Mar  8 15:31 NYSE_2015.txt.gz
# -rw-r--r-- 1 ajay ajay 10552757 Mar  8 15:31 NYSE_2014.txt.gz
# -rw-r--r-- 1 ajay ajay  9588984 Mar  8 15:31 NYSE_2013.txt.gz
# -rw-r--r-- 1 ajay ajay  8538688 Mar  8 15:31 NYSE_2012.txt.gz
# -rw-r--r-- 1 ajay ajay  7980961 Mar  8 15:31 NYSE_2011.txt.gz
# -rw-r--r-- 1 ajay ajay  7551218 Mar  8 15:31 NYSE_2010.txt.gz
# -rw-r--r-- 1 ajay ajay  7179621 Mar  8 15:31 NYSE_2008.txt.gz
# -rw-r--r-- 1 ajay ajay  7186235 Mar  8 15:31 NYSE_2009.txt.gz
# -rw-r--r-- 1 ajay ajay  6903056 Mar  8 15:31 NYSE_2007.txt.gz
# -rw-r--r-- 1 ajay ajay  6480175 Mar  8 15:31 NYSE_2006.txt.gz
# ...

# %%
ls -lSR
# Out:
# .:
# total 8
# drwxr-xr-x 2 ajay ajay 4096 Mar  8 15:31 nyse_data/
# drwxr-xr-x 2 ajay ajay 4096 Mar  8 15:31 nyse_stocks/
#
# ./nyse_data:
# total 136020
# -rw-r--r-- 1 ajay ajay 11796756 Mar  8 15:31 NYSE_2016.txt.gz
# -rw-r--r-- 1 ajay ajay 11327417 Mar  8 15:31 NYSE_2015.txt.gz
# -rw-r--r-- 1 ajay ajay 10552757 Mar  8 15:31 NYSE_2014.txt.gz
# -rw-r--r-- 1 ajay ajay  9588984 Mar  8 15:31 NYSE_2013.txt.gz
# -rw-r--r-- 1 ajay ajay  8538688 Mar  8 15:31 NYSE_2012.txt.gz
# -rw-r--r-- 1 ajay ajay  7980961 Mar  8 15:31 NYSE_2011.txt.gz
# -rw-r--r-- 1 ajay ajay  7551218 Mar  8 15:31 NYSE_2010.txt.gz
# -rw-r--r-- 1 ajay ajay  7186235 Mar  8 15:31 NYSE_2009.txt.gz
# -rw-r--r-- 1 ajay ajay  7179621 Mar  8 15:31 NYSE_2008.txt.gz
# -rw-r--r-- 1 ajay ajay  6903056 Mar  8 15:31 NYSE_2007.txt.gz
# -rw-r--r-- 1 ajay ajay  6480175 Mar  8 15:31 NYSE_2006.txt.gz
# -rw-r--r-- 1 ajay ajay  6207833 Mar  8 15:31 NYSE_2005.txt.gz
# -rw-r--r-- 1 ajay ajay  5689069 Mar  8 15:31 NYSE_2004.txt.gz
# ...

# %%
ls -lRr
# Out:
# .:
# total 8
# drwxr-xr-x 2 ajay ajay 4096 Mar  8 15:31 nyse_stocks/
# drwxr-xr-x 2 ajay ajay 4096 Mar  8 15:31 nyse_data/
#
# ./nyse_stocks:
# total 388
# -rw-r--r-- 1 ajay ajay 394993 Mar  8 15:31 companylist_noheader.csv
#
# ./nyse_data:
# total 136020
# -rw-r--r-- 1 ajay ajay   519586 Mar  8 15:31 NYSE_2017.txt.gz
# -rw-r--r-- 1 ajay ajay 11796756 Mar  8 15:31 NYSE_2016.txt.gz
# -rw-r--r-- 1 ajay ajay 11327417 Mar  8 15:31 NYSE_2015.txt.gz
# -rw-r--r-- 1 ajay ajay 10552757 Mar  8 15:31 NYSE_2014.txt.gz
# -rw-r--r-- 1 ajay ajay  9588984 Mar  8 15:31 NYSE_2013.txt.gz
# -rw-r--r-- 1 ajay ajay  8538688 Mar  8 15:31 NYSE_2012.txt.gz
# -rw-r--r-- 1 ajay ajay  7980961 Mar  8 15:31 NYSE_2011.txt.gz
# -rw-r--r-- 1 ajay ajay  7551218 Mar  8 15:31 NYSE_2010.txt.gz
# -rw-r--r-- 1 ajay ajay  7186235 Mar  8 15:31 NYSE_2009.txt.gz
# -rw-r--r-- 1 ajay ajay  7179621 Mar  8 15:31 NYSE_2008.txt.gz
# -rw-r--r-- 1 ajay ajay  6903056 Mar  8 15:31 NYSE_2007.txt.gz
# ...

# %%
ls -Rr
# Out:
# .:
# nyse_stocks/  nyse_data/
#
# ./nyse_stocks:
# companylist_noheader.csv
#
# ./nyse_data:
# NYSE_2017.txt.gz  NYSE_2011.txt.gz  NYSE_2005.txt.gz  NYSE_1999.txt.gz
# NYSE_2016.txt.gz  NYSE_2010.txt.gz  NYSE_2004.txt.gz  NYSE_1998.txt.gz
# NYSE_2015.txt.gz  NYSE_2009.txt.gz  NYSE_2003.txt.gz  NYSE_1997.txt.gz
# NYSE_2014.txt.gz  NYSE_2008.txt.gz  NYSE_2002.txt.gz
# NYSE_2013.txt.gz  NYSE_2007.txt.gz  NYSE_2001.txt.gz
# NYSE_2012.txt.gz  NYSE_2006.txt.gz  NYSE_2000.txt.gz

# %%
ls -lRr
# Out:
# .:
# total 8
# drwxr-xr-x 2 ajay ajay 4096 Mar  8 15:31 nyse_stocks/
# drwxr-xr-x 2 ajay ajay 4096 Mar  8 15:31 nyse_data/
#
# ./nyse_stocks:
# total 388
# -rw-r--r-- 1 ajay ajay 394993 Mar  8 15:31 companylist_noheader.csv
#
# ./nyse_data:
# total 136020
# -rw-r--r-- 1 ajay ajay   519586 Mar  8 15:31 NYSE_2017.txt.gz
# -rw-r--r-- 1 ajay ajay 11796756 Mar  8 15:31 NYSE_2016.txt.gz
# -rw-r--r-- 1 ajay ajay 11327417 Mar  8 15:31 NYSE_2015.txt.gz
# -rw-r--r-- 1 ajay ajay 10552757 Mar  8 15:31 NYSE_2014.txt.gz
# -rw-r--r-- 1 ajay ajay  9588984 Mar  8 15:31 NYSE_2013.txt.gz
# -rw-r--r-- 1 ajay ajay  8538688 Mar  8 15:31 NYSE_2012.txt.gz
# -rw-r--r-- 1 ajay ajay  7980961 Mar  8 15:31 NYSE_2011.txt.gz
# -rw-r--r-- 1 ajay ajay  7551218 Mar  8 15:31 NYSE_2010.txt.gz
# -rw-r--r-- 1 ajay ajay  7186235 Mar  8 15:31 NYSE_2009.txt.gz
# -rw-r--r-- 1 ajay ajay  7179621 Mar  8 15:31 NYSE_2008.txt.gz
# -rw-r--r-- 1 ajay ajay  6903056 Mar  8 15:31 NYSE_2007.txt.gz
# ...

# %%
ls -alRr
# Out:
# .:
# total 16
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 nyse_stocks/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 nyse_data/
# drwxr-xr-x 12 ajay ajay 4096 Mar  8 15:31 ../
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 ./
#
# ./nyse_stocks:
# total 396
# -rw-r--r-- 1 ajay ajay 394993 Mar  8 15:31 companylist_noheader.csv
# drwxr-xr-x 4 ajay ajay   4096 Mar  8 15:31 ../
# drwxr-xr-x 2 ajay ajay   4096 Mar  8 15:31 ./
#
# ./nyse_data:
# total 136028
# -rw-r--r-- 1 ajay ajay   519586 Mar  8 15:31 NYSE_2017.txt.gz
# -rw-r--r-- 1 ajay ajay 11796756 Mar  8 15:31 NYSE_2016.txt.gz
# -rw-r--r-- 1 ajay ajay 11327417 Mar  8 15:31 NYSE_2015.txt.gz
# -rw-r--r-- 1 ajay ajay 10552757 Mar  8 15:31 NYSE_2014.txt.gz
# -rw-r--r-- 1 ajay ajay  9588984 Mar  8 15:31 NYSE_2013.txt.gz
# -rw-r--r-- 1 ajay ajay  8538688 Mar  8 15:31 NYSE_2012.txt.gz
# -rw-r--r-- 1 ajay ajay  7980961 Mar  8 15:31 NYSE_2011.txt.gz
# -rw-r--r-- 1 ajay ajay  7551218 Mar  8 15:31 NYSE_2010.txt.gz
# ...

# %% [markdown]
# # Exploring Control Arguments while listing files in linux

# %%
cd ~
# Out:
# /home/ajay

# %%
cd data/
# Out:
# /home/ajay/data

# %% [markdown]
# Human readable formate

# %%
ls -lRh
# Out:
# .:
# total 40K
# -rw-r--r--  1 ajay ajay  160 Mar  8 15:31 README.md
# drwxr-xr-x  4 ajay ajay 4.0K Mar  8 16:01 cards/
# drwxr-xr-x  2 ajay ajay 4.0K Mar  8 15:31 electionresults/
# drwxr-xr-x  2 ajay ajay 4.0K Mar  8 15:31 hr/
# drwxr-xr-x 10 ajay ajay 4.0K Mar  8 15:31 hr_db/
# drwxr-xr-x  2 ajay ajay 4.0K Mar  8 15:59 lca/
# drwxr-xr-x  2 ajay ajay 4.0K Mar  8 15:31 nyse/
# drwxr-xr-x  4 ajay ajay 4.0K Mar  8 15:31 nyse_all/
# drwxr-xr-x  8 ajay ajay 4.0K Mar  8 15:31 retail_db/
# drwxr-xr-x  8 ajay ajay 4.0K Mar  8 15:31 retail_db_json/
#
# ./cards:
# total 3.4M
# -rw-r--r-- 1 ajay ajay  693 Mar  8 15:31 deckofcards.txt
# -rw-r--r-- 1 ajay ajay 3.4M Mar  8 15:31 largedeck.txt.gz
# drwxr-xr-x 2 ajay ajay 4.0K Mar  8 15:31 smalldecks/
# drwxr-xr-x 2 ajay ajay 4.0K Mar  8 15:31 zippeddecks/
#
# ./cards/smalldecks:
# total 17M
# -rw-r--r-- 1 ajay ajay 5.3M Mar  8 15:31 deckofcards.tar.gz
# -rw-r--r-- 1 ajay ajay  11M Mar  8 15:31 deckofcards.txt
#
# ./cards/zippeddecks:
# ...

# %%
cd nyse_all/nyse_data/
# Out:
# /home/ajay/data/nyse_all/nyse_data

# %%
ls -lh
# Out:
# total 133M
# -rw-r--r-- 1 ajay ajay 3.7M Mar  8 15:31 NYSE_1997.txt.gz
# -rw-r--r-- 1 ajay ajay 4.0M Mar  8 16:56 NYSE_1998.txt.gz
# -rw-r--r-- 1 ajay ajay 4.1M Mar  8 15:31 NYSE_1999.txt.gz
# -rw-r--r-- 1 ajay ajay 4.3M Mar  8 15:31 NYSE_2000.txt.gz
# -rw-r--r-- 1 ajay ajay 4.6M Mar  8 15:31 NYSE_2001.txt.gz
# -rw-r--r-- 1 ajay ajay 4.8M Mar  8 15:31 NYSE_2002.txt.gz
# -rw-r--r-- 1 ajay ajay 5.1M Mar  8 15:31 NYSE_2003.txt.gz
# -rw-r--r-- 1 ajay ajay 5.5M Mar  8 15:31 NYSE_2004.txt.gz
# -rw-r--r-- 1 ajay ajay 6.0M Mar  8 15:31 NYSE_2005.txt.gz
# -rw-r--r-- 1 ajay ajay 6.2M Mar  8 15:31 NYSE_2006.txt.gz
# -rw-r--r-- 1 ajay ajay 6.6M Mar  8 15:31 NYSE_2007.txt.gz
# -rw-r--r-- 1 ajay ajay 6.9M Mar  8 15:31 NYSE_2008.txt.gz
# -rw-r--r-- 1 ajay ajay 6.9M Mar  8 15:31 NYSE_2009.txt.gz
# -rw-r--r-- 1 ajay ajay 7.3M Mar  8 15:31 NYSE_2010.txt.gz
# -rw-r--r-- 1 ajay ajay 7.7M Mar  8 15:31 NYSE_2011.txt.gz
# -rw-r--r-- 1 ajay ajay 8.2M Mar  8 15:31 NYSE_2012.txt.gz
# ...

# %% [markdown]
# # most comman used command

# %%
ll
# Out:
# total 40
# -rw-r--r--  1 ajay  160 Mar  8 15:31 README.md
# drwxr-xr-x  4 ajay 4096 Mar  8 16:01 cards/
# drwxr-xr-x  2 ajay 4096 Mar  8 15:31 electionresults/
# drwxr-xr-x  2 ajay 4096 Mar  8 15:31 hr/
# drwxr-xr-x 10 ajay 4096 Mar  8 15:31 hr_db/
# drwxr-xr-x  2 ajay 4096 Mar  8 15:59 lca/
# drwxr-xr-x  2 ajay 4096 Mar  8 15:31 nyse/
# drwxr-xr-x  4 ajay 4096 Mar  8 15:31 nyse_all/
# drwxr-xr-x  8 ajay 4096 Mar  8 15:31 retail_db/
# drwxr-xr-x  8 ajay 4096 Mar  8 15:31 retail_db_json/

# %%
ls -ltr
# Out:
# total 40
# -rw-r--r--  1 ajay ajay  160 Mar  8 15:31 README.md
# drwxr-xr-x 10 ajay ajay 4096 Mar  8 15:31 hr_db/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 hr/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 electionresults/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 nyse/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 nyse_all/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db_json/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:59 lca/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 16:01 cards/

# %%
ls -lt
# Out:
# total 40
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 16:01 cards/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:59 lca/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db_json/
# drwxr-xr-x  8 ajay ajay 4096 Mar  8 15:31 retail_db/
# drwxr-xr-x  4 ajay ajay 4096 Mar  8 15:31 nyse_all/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 nyse/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 electionresults/
# drwxr-xr-x  2 ajay ajay 4096 Mar  8 15:31 hr/
# drwxr-xr-x 10 ajay ajay 4096 Mar  8 15:31 hr_db/
# -rw-r--r--  1 ajay ajay  160 Mar  8 15:31 README.md

# %% [markdown]
# ![image.png](attachment:b4695f06-1ff1-48bf-bd4b-cb94b256dedc.png)

# %% [markdown]
# ![image.png](attachment:af899121-2bce-4a71-a347-596e1e10c155.png)

# %% [markdown]
# ![image.png](attachment:97057379-04c1-461f-baa4-3498e5ae59a7.png)

# %% [markdown]
# ![image.png](attachment:86e9ebe2-721f-4acf-9354-211760702138.png)

# %% [markdown]
# ![image.png](attachment:06255e0f-c0a5-4302-b996-fa1f8c73b1a8.png)

# %% [markdown]
# ![image.png](attachment:8ee9e8b8-c6a3-4e03-bfee-c8f5cf002691.png)

# %% [markdown]
# ![image.png](attachment:d6962d45-2c44-4d5a-8aa0-6c589d8cf317.png)

# %% [markdown]
# ![image.png](attachment:6d9def77-7e18-48dc-8bfd-9cc9528ecd40.png)
